# %% [markdown]
# # Decision Tree Algorithm-Task4

# %% [markdown]
# #### create the Decision Tree classifier and visualize it graphically for the given iris dataset

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.datasets as datasets

# %%
# Load the iris dataset
# Loading the iris dataset
iris=datasets.load_iris()

# %%
df=pd.DataFrame(iris.data, columns=iris.feature_names)
y=iris.target

# %%
# Defining the decision tree algorithm
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier()
classifier.fit(df,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %% [markdown]
# from sklearn.metrics import accuracy_score
# acc=accuracy_score(y_test,y_pred)
# acc

# %% [markdown]
# #### Let us Visualise the Decision Tree

# %%
from sklearn import tree
fig=plt.figure(figsize=(40,50))
viz=tree.plot_tree(classifier,feature_names=df.columns,class_names=iris.target_names,filled=True)
